# %% [markdown]
# # calculating fraction infectivities from excel output plate reader files
# This notebook uses `excel_to_fractinfect_TM_InputFolder.py` to calculate fraction infectivities based on plate reader excel files in the subfolder `raw_plate_reader`. For the most part experiments are seperated by date, see `ExperimentDates.txt` for more details and for information on which fraction infectivities were instead calculated 'manually'.
#
# # outliers removed
# - This version of the script removes any data points whose fraction infectivity lies over 1.5 to remove the most extreme outliers from the data set and hopefully reduce the noise on the curves (inidicated by or in file name).
# - This version of the script DOES NOT normalize the IC50s of each sample. There is another version of the script with normalized in the file name that does this.
#
# `excel_to_fractinfect_TM_InputFolder.py` is a script that takes:
# - a **folder** containing excel output files from the SkanIt plate reader software (make sure none of these are open on your device before running or you will get an error about the excel file type being unknown)
#     - raw_plate_reader/your_file_name
# - a **plate layout** from the PlateLayout folder located in the 'route' folder which defines sample positions in the plate
#     - defaults to the LayoutTM.csv layout
# - a **plate map**, which is a .csv which links the plate name to sample names and viruses tested, starting concentration, dilution factor **plate layout** file etc.
#     - maps/your_file_name
# - there are **two versions** of this script:
#     - 'excel_to_fractinfect_TM_InputFolder.py': converts RLU to FI using the average pos_ctrl data for each plate
#     - 'excel_to_fractinfect_TM_InputFolder_perrow.py': converts RLU to FI using each row's associated pos_ctrl value
#     - specify the version after %run
#
# The script outputs a processed file in the formt accepted by the neutcurve package. You should provide a descriptive name for this file.
# -   frac_infect/your_file_name
#
# The **plate map** has columns:
# - **Date_Read**: this is for record keeping and does not effect analysis
# - **Plate**: the name of the plate, exactly how it appears in the excel plate reader output file (2 cells below the `Wavelength: 0 nm` cell). If this is off by a space or character you will get an error when reading the plate.
# - **Sample**: the sera sample name
# - **SampleNum**: the sample position number designated by the plate layout file
# - **Virus**: the virus added to the sample
# - **PlateLayout**: the name of the file of your plate map that is located in the PlateLayout folder
# - **StartDil**: the starting dilution of sera on the plate
# - **DilFactor**: the dilution factor of the sera, pretty straightfoward.
# - **Orientation**: `V` for vertical/tall (H-A at top) or `H` for horizontal/wide (1-12 at top)
# - **background**: `keep` to keep background `cells only` values (designated in plate layout), `remove` to remove the average negative control RLU value from samples
# Each row of *plate map* must have all of these column values. And each row refers to a sample on the plate. Look at layouts and example plate maps to get a better idea of how this works.
# - **experiment_rep** any value, attached to output fraction infectivity file (used in our case to keep track of experiment type and replicate for each sample/virus+serum combo)

# %%
import pandas as pd
import numpy as np
import neutcurve

from math import floor, log10
from plotnine import *

# %%
from pathlib import Path
import os

from pathlib import Path

os.chdir("/fh/fast/bloom_j/computational_notebooks/gjuviler")
os.getcwd()
# Out:
# '/fh/fast/bloom_j/computational_notebooks/gjuviler'

# %% [markdown]
# ## store all changeable variables:

# %%
original_dataset = "moat_neuts/frac_infect/2026.01.08.15.16.23.29_all_batches_rabvg_perrow.csv"    #this is the dataset that is input in to the outlier removal script

input_template = "rabies_imprinting/01-data/batch_control_slope_plot_input_template.csv"     #path to and name of the slope plot input template, with blank id50 columns. This can usually be left the same, but edit for different sera, etc.

slope_plot_input = "rabies_imprinting/01-data/26.02.19_batch_control_slope_plot_input.csv"     #provide a path and name for the slope plot input format with the id50s filled in 

plots_name = "rabies_imprinting/03-results/26.02.19_batch_control_median.html"      #provide a path and name for the saved altair plots in html format 

svg_name = "rabies_imprinting/03-results/26.02.19_batch_control_median.svg"      #provide a path and name for the saved altair plots in svg format

# %% [markdown]
# ## Convert

# %%
#run script
# %run moat_neuts/excel_to_fractinfect_TM_InputFolder_perrow.py moat_neuts/raw_plate_reader/26.02.04_all_batches/ moat_neuts/frac_infect/2026.01.08.15.16.23.29_all_batches_rabvg_perrow.csv moat_neuts/maps/2026.08.15.16.23.29_all_batches_rabvg_map.csv moat_neuts/PlateLayouts
# Out:
# Processing file: moat_neuts/raw_plate_reader/26.02.04_all_batches/260108_neuts.xlsx
# Processing plate: Plate 1
# Processing plate: Plate 2
# Processing plate: Plate 3
# Processing plate: Plate 4
# Processing plate: Plate 5
# Processing file: moat_neuts/raw_plate_reader/26.02.04_all_batches/260115_neuts.xlsx
# Processing plate: Plate 1_15
# Processing plate: Plate 2_15
# Processing plate: Plate 3_15
# Processing plate: Plate 4_15
# Processing plate: Plate 5_15
# Processing plate: Plate 6_15
# Processing file: moat_neuts/raw_plate_reader/26.02.04_all_batches/260116_neuts.xlsx
# Processing plate: Plate 1_16
# Processing plate: Plate 2_16
# Processing plate: Plate 3_16
# Processing plate: Plate 4_16
# Processing plate: Plate 5_16
# Processing plate: Plate 6_16
# Processing plate: Plate 7_16
# Processing plate: Plate 8_16
# Processing file: moat_neuts/raw_plate_reader/26.02.04_all_batches/260123_neuts.xlsx
# Processing plate: Plate 1_23
# Processing plate: Plate 2_23
# Processing plate: Plate 3_23
# Processing plate: Plate 4_23
# Processing plate: Plate 5_23
# Processing plate: Plate 6_23
# Processing plate: Plate 7_23
# Processing plate: Plate 8_23
# Processing file: moat_neuts/raw_plate_reader/26.02.04_all_batches/260129_neuts.xlsx
# Processing plate: Plate 1_29
# Processing plate: Plate 2_29
# Processing plate: Plate 3_29
# Processing plate: Plate 4_29
# Processing plate: Plate 5_29
# Processing plate: Plate 6_29
# Processing plate: Plate 7_29
# Processing plate: Plate 8_29

# %% [markdown]
# ## plot original dataset, generate ic50 table

# %%
datafile = original_dataset
data = pd.read_csv(datafile)
data.head()
# Out:
#     serum               virus  replicate  concentration well_id plate_name  \
# 0  01-d28  Batch 1 (26.01.08)          1        0.20000      F2    Plate 1
# 1  01-d28  Batch 1 (26.01.08)          1        0.04000      F3    Plate 1
# 2  01-d28  Batch 1 (26.01.08)          1        0.00800      F4    Plate 1
# 3  01-d28  Batch 1 (26.01.08)          1        0.00160      F5    Plate 1
# 4  01-d28  Batch 1 (26.01.08)          1        0.00032      F6    Plate 1
#
#    experiment_rep  fraction infectivity          input_folder
# 0             NaN              0.000014  26.02.04_all_batches
# 1             NaN              0.000937  26.02.04_all_batches
# 2             NaN              0.036150  26.02.04_all_batches
# 3             NaN              0.091200  26.02.04_all_batches
# 4             NaN              0.165200  26.02.04_all_batches

# %%
data.tail()
# Out:
#         serum               virus  replicate  concentration well_id  \
# 1885  32-d365  Batch 5 (26.01.29)          2   3.200000e-04      C6
# 1886  32-d365  Batch 5 (26.01.29)          2   6.400000e-05      C7
# 1887  32-d365  Batch 5 (26.01.29)          2   1.280000e-05      C8
# 1888  32-d365  Batch 5 (26.01.29)          2   2.560000e-06      C9
# 1889  32-d365  Batch 5 (26.01.29)          2   5.120000e-07     C10
#
#       plate_name  experiment_rep  fraction infectivity          input_folder
# 1885  Plate 8_29             NaN                0.6826  26.02.04_all_batches
# 1886  Plate 8_29             NaN                0.8341  26.02.04_all_batches
# 1887  Plate 8_29             NaN                0.8483  26.02.04_all_batches
# 1888  Plate 8_29             NaN                1.0260  26.02.04_all_batches
# 1889  Plate 8_29             NaN                1.0410  26.02.04_all_batches

# %%
fits = neutcurve.CurveFits(data, fixtop=(1), fixslope=(0.5,2))
fig, axes = fits.plotViruses(xlabel="concentration (relative)", fix_lims = {"ymax": 1.5}, sera = ['02-d28 (08)', '02-d56 (08)', '02-d365 (08)', '02-d28 (15)', '02-d56 (15)', '02-d365 (15)', '02-d28 (16)', '02-d56 (16)', '02-d365 (16)', '02-d28 (23)', '02-d56 (23)', '02-d365 (23)', '02-d28 (29)', '02-d56 (29)', '02-d365 (29)'], max_sera_per_subplot=3)
for ax in axes.flatten():
    leg = ax.get_legend()
    if leg is not None:
        leg.set_bbox_to_anchor((1, 1))     # move legend to top right of axes
        leg._loc = 1                       # 1 = upper right
        # Or: leg.set_loc("upper right")   # if your MPL version supports it


ic50_table = fits.fitParams()   #ic50 table for non outlier removed data
fits.fitParams()
# Out:
# /home/gjuviler/miniforge3/envs/juviler_jup/lib/python3.14/site-packages/neutcurve/hillcurve.py:1179: RuntimeWarning: invalid value encountered in power
#            serum               virus replicate  nreplicates      ic50  \
# 0         01-d28  Batch 1 (26.01.08)   average            2  0.000033
# 1         01-d56  Batch 1 (26.01.08)   average            2  0.000073
# 2        01-d365  Batch 1 (26.01.08)   average            2  0.000221
# 3    02-d28 (08)  Batch 1 (26.01.08)   average            2  0.000012
# 4    02-d56 (08)  Batch 1 (26.01.08)   average            2  0.000059
# ..           ...                 ...       ...          ...       ...
# 100       31-d56  Batch 5 (26.01.29)   average            2  0.000756
# 101      31-d365  Batch 5 (26.01.29)   average            2  0.001637
# 102       32-d28  Batch 5 (26.01.29)   average            2  0.000084
# 103       32-d56  Batch 5 (26.01.29)   average            2  0.000420
# 104      32-d365  Batch 5 (26.01.29)   average            2  0.000809
#
#        ic50_bound  ic50_str  midpoint  midpoint_bound midpoint_bound_type  \
# 0    interpolated  3.28e-05  0.000033        0.000033        interpolated
# 1    interpolated  7.34e-05  0.000073        0.000073        interpolated
# 2    interpolated  0.000221  0.000221        0.000221        interpolated
# 3    interpolated  1.23e-05  0.000012        0.000012        interpolated
# 4    interpolated  5.92e-05  0.000059        0.000059        interpolated
# ..            ...       ...       ...             ...                 ...
# 100  interpolated  0.000756  0.000756        0.000756        interpolated
# 101  interpolated   0.00164  0.001637        0.001637        interpolated
# 102  interpolated   8.4e-05  0.000084        0.000084        interpolated
# 103  interpolated   0.00042  0.000420        0.000420        interpolated
# 104  interpolated  0.000809  0.000809        0.000809        interpolated
#
#         slope  top  bottom        r2      rmsd
# 0    0.883480  1.0     0.0  0.797521  0.228742
# 1    0.572218  1.0     0.0  0.995060  0.025246
# 2    0.759115  1.0     0.0  0.909374  0.135908
# 3    0.679813  1.0     0.0  0.996137  0.020562
# 4    0.619951  1.0     0.0  0.970955  0.060276
# ..        ...  ...     ...       ...       ...
# 100  0.852659  1.0     0.0  0.994845  0.029507
# 101  0.956606  1.0     0.0  0.906899  0.141845
# 102  0.763513  1.0     0.0  0.994702  0.029234
# 103  0.893647  1.0     0.0  0.997138  0.022641
# 104  0.800307  1.0     0.0  0.975265  0.066157
#
# [105 rows x 15 columns]

# %% [markdown]
# ## convert each ic50 to id50 by taking the inverse

# %%
id50s = []   #list of normalized id50 values

#take the inverse of each ic50 and store the resulting values in a list of id50s
for index, ic50 in enumerate(ic50_table.iloc[:, 4]):
    if ic50_table.iloc[index, 0].startswith('02') == True:
        id50s.append(1/ic50)     #store the normalized ic50s in a list called or_id50s

print(id50s)
# Out:
# [81571.63910004216, 16879.414959294703, 5760.494336396771, 63218.73607976818, 9299.800197612298, 9198.912350479664, 5289.294563543085, 1804.2433040137448, 427.8100418339493, 7576.479403926263, 1427.5310485558814, 332.4274173632113, 24491.999612498155, 6231.628213488522, 2751.14273303704]

# %% [markdown]
# ## add the list of id50 values to the slope plot input format

# %%
df_input = pd.read_csv(input_template)

for index, value in enumerate(df_input.iloc[:15, 3]):
    df_input.iloc[index, 3] = id50s[index]
    df_input.iloc[index, 4] = id50s[index]

"""
for index, value in enumerate(df_input.iloc[:, 5]):    
    df_input.iloc[index, 5] = df_input.iloc[index, 5] + " (out. rem.)"
"""
df_input.to_csv(slope_plot_input, index = False)
df_input
# Out:
#     serum virus   ID      dilution         value  \
# 0       2   d28  0.5  81571.639100  81571.639100
# 1       2   d56  0.5  16879.414959  16879.414959
# 2       2  d365  0.5   5760.494336   5760.494336
# 3       2   d28  0.5  63218.736080  63218.736080
# 4       2   d56  0.5   9299.800198   9299.800198
# 5       2  d365  0.5   9198.912350   9198.912350
# 6       2   d28  0.5   5289.294564   5289.294564
# 7       2   d56  0.5   1804.243304   1804.243304
# 8       2  d365  0.5    427.810042    427.810042
# 9       2   d28  0.5   7576.479404   7576.479404
# 10      2   d56  0.5   1427.531049   1427.531049
# 11      2  d365  0.5    332.427417    332.427417
# 12      2   d28  0.5  24491.999612  24491.999612
# 13      2   d56  0.5   6231.628213   6231.628213
# 14      2  d365  0.5   2751.142733   2751.142733
#
#                        serum group      batch
# 0   Participant 02 (Batch Control)  26.01.08
# 1   Participant 02 (Batch Control)  26.01.08
# 2   Participant 02 (Batch Control)  26.01.08
# 3   Participant 02 (Batch Control)  26.01.15
# 4   Participant 02 (Batch Control)  26.01.15
# 5   Participant 02 (Batch Control)  26.01.15
# 6   Participant 02 (Batch Control)   26.01.16
# 7   Participant 02 (Batch Control)   26.01.16
# 8   Participant 02 (Batch Control)   26.01.16
# 9   Participant 02 (Batch Control)   26.01.23
# 10  Participant 02 (Batch Control)   26.01.23
# 11  Participant 02 (Batch Control)   26.01.23
# 12  Participant 02 (Batch Control)   26.01.29
# 13  Participant 02 (Batch Control)   26.01.29
# 14  Participant 02 (Batch Control)   26.01.29

# %% [markdown]
# ## Create the slope plots from the input file
# The following code is adapted from slope_plots_26.01.30.ipynb, which was adapted from an extremely long Marimo notebook that Caelan sent me called 2025 - 11 - 21 RABVG neuts.py

# %%
import warnings
from matplotlib import pyplot as plt
import altair as alt
from pathlib import Path
from typing import List, Dict, Optional, Tuple

# %%
"""Configuration parameters."""
# Input/output settings
ID_table = pd.read_csv(slope_plot_input).iloc[:15, :]
output_dir = "results/"

# Plotting parameters
plot_dpi = 300
curve_ymax = 1.2

# Slope plot options
generate_slope_plots = True  # Set to False to skip slope plot generation
use_id_for_slope = True  # If True, use ID50 instead of IC50 in slope plots
serum_groups_to_plot = None  # List of serum groups to include in slope plots, or None for all
# Example: serum_groups_to_plot = ['C-1', 'C-2', 'IgG']

# Note: This file now supports multiple viruses per plate!
# Format: virus=,,virus1,virus1,virus2,virus2,...

ID_table
# Out:
#     serum virus   ID      dilution         value  \
# 0       2   d28  0.5  81571.639100  81571.639100
# 1       2   d56  0.5  16879.414959  16879.414959
# 2       2  d365  0.5   5760.494336   5760.494336
# 3       2   d28  0.5  63218.736080  63218.736080
# 4       2   d56  0.5   9299.800198   9299.800198
# 5       2  d365  0.5   9198.912350   9198.912350
# 6       2   d28  0.5   5289.294564   5289.294564
# 7       2   d56  0.5   1804.243304   1804.243304
# 8       2  d365  0.5    427.810042    427.810042
# 9       2   d28  0.5   7576.479404   7576.479404
# 10      2   d56  0.5   1427.531049   1427.531049
# 11      2  d365  0.5    332.427417    332.427417
# 12      2   d28  0.5  24491.999612  24491.999612
# 13      2   d56  0.5   6231.628213   6231.628213
# 14      2  d365  0.5   2751.142733   2751.142733
#
#                        serum group      batch
# 0   Participant 02 (Batch Control)  26.01.08
# 1   Participant 02 (Batch Control)  26.01.08
# 2   Participant 02 (Batch Control)  26.01.08
# 3   Participant 02 (Batch Control)  26.01.15
# 4   Participant 02 (Batch Control)  26.01.15
# 5   Participant 02 (Batch Control)  26.01.15
# 6   Participant 02 (Batch Control)   26.01.16
# 7   Participant 02 (Batch Control)   26.01.16
# 8   Participant 02 (Batch Control)   26.01.16
# 9   Participant 02 (Batch Control)   26.01.23
# 10  Participant 02 (Batch Control)   26.01.23
# 11  Participant 02 (Batch Control)   26.01.23
# 12  Participant 02 (Batch Control)   26.01.29
# 13  Participant 02 (Batch Control)   26.01.29
# 14  Participant 02 (Batch Control)   26.01.29

# %%
"""Prepare data for slope plots."""

                      
if not generate_slope_plots:
    print("Slope plot generation disabled (generate_slope_plots = False)")
    slope_data = None
    virus_order = []
    plot_label = 'IC50'
    y_label = 'IC50 (nM)'
else:
    # Determine which table and settings to use
    if use_id_for_slope and ID_table is not None:
        table_to_plot = ID_table
        value_col = 'dilution'
        plot_label = 'Batch Control NT50'
        y_label = 'NT50 (Neutralization Titer)'
        print("Using ID50 values for slope plot")
    else:
        table_to_plot = IC_table
        value_col = 'concentration'
        plot_label = 'IC50'
        y_label = 'IC50 (nM)'
        print("Using IC50 values for slope plot")

    # Prepare slope data with optional serum group filtering
    """BlockingIOError
    slope_data = prepare_slope_data(
        table_to_plot,
        value_col=value_col,
        ic_or_id_value=0.50,
        serum_groups_filter=serum_groups_to_plot
    )
    """
"""
    if len(slope_data) > 0:
        virus_order = natsort.natsorted(slope_data['virus'].unique().tolist())
        print(f"Prepared slope data: {len(slope_data)} points across {len(virus_order)} viruses")
    else:
        virus_order = []
        print(f"Warning: No valid slope data (all {plot_label} values are 0 or missing)")
        """
# Out:
# Using ID50 values for slope plot
# '\n    if len(slope_data) > 0:\n        virus_order = natsort.natsorted(slope_data[\'virus\'].unique().tolist())\n        print(f"Prepared slope data: {len(slope_data)} points across {len(virus_order)} viruses")\n    else:\n        virus_order = []\n        print(f"Warning: No valid slope data (all {plot_label} values are 0 or missing)")\n        '

# %%
virus_order = ["d28", "d56", "d365"]
highlight = alt.selection_point(fields=['serum'], on='mouseover', nearest=True)

# Individual serum lines
individual_lines = (
    alt.Chart(ID_table)
    .mark_line(point=True)
    .encode(
        x=alt.X('virus:N', sort=virus_order, title=None),
        y=alt.Y('value:Q',
                scale=alt.Scale(type='log'),
                title=y_label),
        color=alt.Color(
            'batch:N', title='Batch', 
            legend=alt.Legend(
                titleFontSize=18,
                labelFontSize=16,
                symbolSize=150
            )
        ),
        detail='serum:N',
        opacity=alt.condition(highlight, alt.value(1), alt.value(0.4)),
        tooltip=['serum', 'serum group:N', 'virus',
                 alt.Tooltip('value', format='.3f', title=y_label)]
    )
    .add_params(highlight)
)

# Explicit median aggregation
median_line = (
    alt.Chart(ID_table)
    .transform_aggregate(
        median_value='median(value)',
        groupby=['virus', 'serum group']
    )
    .mark_line(color='black', strokeWidth=4)
    .encode(
        x=alt.X('virus:N', sort=virus_order),
        y=alt.Y('median_value:Q',
                scale=alt.Scale(type='log'))
    )
)

median_points = (
    alt.Chart(ID_table)
    .transform_aggregate(
        median_value='median(value)',
        groupby=['virus', 'serum group']
    )
    .mark_point(color='black', size=50)
    .encode(
        x=alt.X('virus:N', sort=virus_order, axis=alt.Axis(
                #makes the x axis labels sit horizontally, centered under the ticks
                labelAngle=0,       
                labelAlign='center',
                labelBaseline ='top',
                labelPadding=6
                )
        ),
        y=alt.Y('median_value:Q',
                scale=alt.Scale(type='log'), axis=alt.Axis(labelPadding=6))
    )
)

base_chart = alt.layer(
    individual_lines,
    median_line,
    median_points
).properties(width=250, height=350)

faceted_chart = (
    base_chart
    .facet(column=alt.Column('serum group:N', title='Serum Group'))
    .configure_axisX(
        ticks=True,
        labelFontSize=18,
        titleFontSize=18,
        domainWidth=2,
        tickWidth=2,
        domainColor='black'
    )
    .configure_axisY(
        ticks=False,
        labelFontSize=14,
        titleFontSize=18,
        domainWidth = 2,
        domainColor='black'
    )
    .configure_header(
        labelFontSize=18,
        titleFontSize=18
    )
    .configure_title(
        fontSize=22
    )
    .properties(title=f'{plot_label} Slope Plot')
)


faceted_chart.save(plots_name)
faceted_chart.save(svg_name)
faceted_chart
# Out:
# alt.FacetChart(...)
